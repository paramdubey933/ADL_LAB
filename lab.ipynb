# %% [markdown]
# ## Simple Linear Regression

# %%
import pandas as pd

df = pd.read_csv("./student_scores.csv")
df.head(10)
# Out:
#    Hours  Scores
# 0    2.5      21
# 1    5.1      47
# 2    3.2      27
# 3    8.5      75
# 4    3.5      30
# 5    1.5      20
# 6    9.2      88
# 7    5.5      60
# 8    8.3      81
# 9    2.7      25

# %%
X = df[['Hours']]
Y = df['Scores']

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(X,Y, test_size=0.2)

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
x_train.shape, x_test.shape, y_train.shape
# Out:
# ((20, 1), (5, 1), (20,))

# %%
y_pred = model.predict(x_test)
y_pred, y_test
# Out:
# (array([28.28837901, 34.89358889, 22.62677054, 69.8068411 , 30.17558183]),
#  0     21
#  2     27
#  17    24
#  23    76
#  9     25
#  Name: Scores, dtype: int64)

# %%
model.score(x_train, y_train)
# Out:
# 0.9505599771200297

# %%
model.score(x_test, y_test)
# Out:
# 0.9155761439533108

# %%
c = model.intercept_
m = model.coef_

# %% [markdown]
# Prediction

# %%
model.predict([[6.4]])
# Out:
# C:\Users\KIIT0001\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([65.08883404])

# %%
y = m*(6.4) + c
y
# Out:
# array([65.08883404])

# %%
v = 6.4
import numpy as np
va = np.array(6.4)
va
# Out:
# array(6.4)

# %%
import matplotlib.pyplot as plt
plt.scatter(X,Y)
plt.plot(x_test, y_test, color='blue')
plt.show()

# %% [markdown]
# ## Multi-Student

# %%
mdf = pd.read_csv("student_multi.csv")
mdf.columns
# Out:
# Index(['Hours', 'IQ', 'Sleep', 'Scores'], dtype='object')

# %%
mX = mdf[['Hours', 'IQ', 'Sleep']]
mY = mdf['Scores']

# %%
mx_train, mx_test, my_train, my_test = train_test_split(mX,mY, test_size=0.2)

# %%
m_model = LinearRegression()
m_model.fit(mx_train, my_train)
# Out:
# LinearRegression()

# %%
my_pred = m_model.predict(mx_test)

my_pred, my_test
# Out:
# (array([110.71348749,  80.91808572,  68.22311066,  78.58198396,
#         121.68603826,  35.03804549,  87.21843297, 101.10166759,
#         117.01383474,  40.45730241]),
#  36    111
#  20     82
#  14     70
#  19     80
#  41    120
#  0      35
#  23     88
#  31    103
#  39    116
#  1      38
#  Name: Scores, dtype: int64)

# %%
trnscore = m_model.score(mx_train, my_train)
tstscore = m_model.score(mx_test, my_test)

trnscore, tstscore
# Out:
# (0.9985246810793719, 0.9974815686772306)

# %%
m_model.predict([[7.3,120,7]])
# Out:
# C:\Users\KIIT0001\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([96.61604223])

# %% [markdown]
# ### RMSE, SME, MEAN ERROR

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
y_true = my_test
mae = mean_absolute_error(y_true, my_pred)
mse = mean_squared_error(y_true, my_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_true, my_pred)
adj_r2 = 1 - (1 - r2) * (len(y_true) - 1) / (len(y_true) - y_true.ndim - 1)

residuals = np.array(y_true) - np.array(my_pred)

print("residuls:", residuals)
print("MAE:", mae)
print("MSE:", mse)
print("RMSE:", rmse)
print("R2:", r2)
print("Adjusted R2:", adj_r2)
# Out:
# residuls: [ 0.28651251  1.08191428  1.77688934  1.41801604 -1.68603826 -0.03804549
#   0.78156703  1.89833241 -1.01383474 -2.45730241]
# MAE: 1.2438452501420343
# MSE: 2.0545614574285214
# RMSE: 1.4333741512349527
# R2: 0.9974815686772306
# Adjusted R2: 0.9971667647618844
